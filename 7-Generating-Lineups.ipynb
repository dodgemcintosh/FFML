# %% [markdown]
# # Using Optimization Techniques to Generate Winning Lineups
# ___
# Until I build one from scratch I'm going to be using `pydfs-lineup-optimizer` to generate optimal lineups with projections that I already have. More information about `pydfs-lineup-optimizer` can be found [here](https://github.com/DimaKudosh/pydfs-lineup-optimizer/tree/master/pydfs_lineup_optimizer/sites/fanduel).

# %% [markdown]
# **Here is one quick example of generating lineups based on average points per game.**

# %%
import pandas as pd
from pydfs_lineup_optimizer import get_optimizer, Site, Sport, CSVLineupExporter

# %%
optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('player-lists/FanDuel-NFL-2018-11-11-29736-players-list.csv')
for lineup in optimizer.optimize(n=10, max_exposure=0.3):
#     print(lineup)
    print(lineup.players)
    print(lineup.fantasy_points_projection)
    print(lineup.salary_costs)
# Out:
# [Ryan Fitzpatrick QB (TB), T.J. Yeldon RB (JAC), Melvin Gordon III RB (LAC), Tyreek Hill WR (KC), Cooper Kupp WR (LAR), DeSean Jackson WR (TB), Eric Ebron TE (IND), Seattle Seahawks D (SEA), Alvin Kamara RB (NO)]
# 154.546
# 60000.0
# [Ryan Fitzpatrick QB (TB), T.J. Yeldon RB (JAC), Melvin Gordon III RB (LAC), Tyreek Hill WR (KC), Cooper Kupp WR (LAR), DeSean Jackson WR (TB), Eric Ebron TE (IND), Arizona Cardinals D (ARI), Alvin Kamara RB (NO)]
# 154.296
# 59400.0
# [Ryan Fitzpatrick QB (TB), T.J. Yeldon RB (JAC), Melvin Gordon III RB (LAC), Tyreek Hill WR (KC), Calvin Ridley WR (ATL), Cooper Kupp WR (LAR), Eric Ebron TE (IND), Arizona Cardinals D (ARI), Alvin Kamara RB (NO)]
# 154.071
# 59700.0
# [Matt Ryan QB (ATL), Todd Gurley II RB (LAR), Isaiah Crowell RB (NYJ), Brandon LaFell WR (OAK), DeSean Jackson WR (TB), Michael Thomas WR (NO), Jared Cook TE (OAK), Arizona Cardinals D (ARI), James White RB (NE)]
# 140.0
# 60000.0
# [Matt Ryan QB (ATL), Todd Gurley II RB (LAR), Isaiah Crowell RB (NYJ), Brandon LaFell WR (OAK), Calvin Ridley WR (ATL), Michael Thomas WR (NO), Nick O'Leary TE (MIA), Seattle Seahawks D (SEA), James White RB (NE)]
# 137.325
# 59900.0
# [Matt Ryan QB (ATL), Todd Gurley II RB (LAR), Isaiah Crowell RB (NYJ), Brandon LaFell WR (OAK), Calvin Ridley WR (ATL), Michael Thomas WR (NO), Nick O'Leary TE (MIA), Miami Dolphins D (MIA), James White RB (NE)]
# 137.283
# 60000.0
# [Andrew Luck QB (IND), Joe Mixon RB (CIN), Kareem Hunt RB (KC), Kenny Golladay WR (DET), Dede Westbrook WR (JAC), Davante Adams WR (GB), Jared Cook TE (OAK), Seattle Seahawks D (SEA), Adrian Peterson RB (WAS)]
# 131.782
# 60000.0
# [Patrick Mahomes QB (KC), Kareem Hunt RB (KC), Tarik Cohen RB (CHI), Kenny Golladay WR (DET), Dede Westbrook WR (JAC), Davante Adams WR (GB), Jared Cook TE (OAK), Chicago Bears D (CHI), Nick O'Leary TE (MIA)]
# 131.774
# 60000.0
# [Patrick Mahomes QB (KC), Joe Mixon RB (CIN), Kareem Hunt RB (KC), Kenny Golladay WR (DET), Dede Westbrook WR (JAC), Tyler Lockett WR (SEA), A.J. Derby TE (MIA), Chicago Bears D (CHI), Adrian Peterson RB (WAS)]
# 129.957
# 60000.0
# [Patrick Mahomes QB (KC), Joe Mixon RB (CIN), Adrian Peterson RB (WAS), Tyler Lockett WR (SEA), Davante Adams WR (GB), Marvin Jones Jr. WR (DET), Michael Roberts TE (DET), Miami Dolphins D (MIA), Tarik Cohen RB (CHI)]
# 127.689
# 59900.0

# %% [markdown]
# **Now instead of just using the average points per game, we'll bring in our other projections that *should* be more accurate.**

# %%
qbs = pd.read_csv('projections/Week-10/DFS - Fanduel QB.csv')
rbs = pd.read_csv('projections/Week-10/DFS - Fanduel RB.csv')
wrs = pd.read_csv('projections/Week-10/DFS - Fanduel WR.csv')
tes = pd.read_csv('projections/Week-10/DFS - Fanduel TE.csv')
dst = pd.read_csv('projections/Week-10/DFS - Fanduel DST.csv')

# %%
qbs.head()
# Out:
#             Player      Opp   Pts Salary  Pts Per 1k
# 0    Aaron Rodgers  vs. MIA  28.4  8,600         3.3
# 1  Patrick Mahomes  vs. ARI  29.2  9,800         3.0
# 2       Drew Brees   at CIN  24.3  8,400         2.9
# 3       Jared Goff  vs. SEA  23.6  8,100         2.9
# 4       Cam Newton   at PIT  24.6  8,700         2.8

# %%
total_projections = pd.concat([qbs,rbs,wrs,tes,dst])
total_projections.rename(columns={"Player": "Nickname"}, inplace=True)

# %%
player_list=pd.read_csv('player-lists/FanDuel-NFL-2018-11-11-29736-players-list.csv')
player_list.head(3)
# Out:
#             Id Position First Name         Nickname  Last Name       FPPG  \
# 0  29736-30447       RB       Todd   Todd Gurley II  Gurley II  26.833333
# 1  29736-57439       QB    Patrick  Patrick Mahomes    Mahomes  27.860001
# 2  29736-45229       RB     Kareem      Kareem Hunt       Hunt  20.888889
#
#    Played  Salary     Game Team Opponent Injury Indicator Injury Details  \
# 0       9   10800  SEA@LAR  LAR      SEA              NaN            NaN
# 1       9    9800   ARI@KC   KC      ARI              NaN            NaN
# 2       9    9000   ARI@KC   KC      ARI              NaN            NaN
#
#    Tier  Unnamed: 14  Unnamed: 15
# 0   NaN          NaN          NaN
# 1   NaN          NaN          NaN
# 2   NaN          NaN          NaN

# %%
player_list.columns
# Out:
# Index(['Id', 'Position', 'First Name', 'Nickname', 'Last Name', 'FPPG',
#        'Played', 'Salary', 'Game', 'Team', 'Opponent', 'Injury Indicator',
#        'Injury Details', 'Tier', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %% [markdown]
# > Merging those 2 and making the swap:

# %%
master_projections = pd.merge(left=player_list, right=total_projections, how='inner', on='Nickname', suffixes=['_FD', '_ballers'])
master_projections['FPPG'] = master_projections['Pts Per 1k'] # Experiment with Pts OR Pts Per 1k
master_projections.drop(['Opp', 'Pts', 'Salary_ballers', 'Pts Per 1k'],axis=1, inplace=True)
master_projections.rename(columns={'Salary_FD':'Salary'}, inplace=True)
master_projections.to_csv('projections/Week-10/master_projections.csv')

# %%
master_projections.head(3)
# Out:
#             Id Position First Name         Nickname Last Name  FPPG  Played  \
# 0  29736-57439       QB    Patrick  Patrick Mahomes   Mahomes   3.0       9
# 1  29736-45229       RB     Kareem      Kareem Hunt      Hunt   3.6       9
# 2  29736-42104       RB      Alvin     Alvin Kamara    Kamara   2.6       8
#
#    Salary    Game Team Opponent Injury Indicator Injury Details  Tier  \
# 0    9800  ARI@KC   KC      ARI              NaN            NaN   NaN
# 1    9000  ARI@KC   KC      ARI              NaN            NaN   NaN
# 2    8800  NO@CIN   NO      CIN              NaN            NaN   NaN
#
#    Unnamed: 14  Unnamed: 15
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN

# %% [markdown]
# ___
# # Alright! Now let's just use our optimizer tools from above to generate some better lineups

# %%
low_tes = list(master_projections.loc[(master_projections['FPPG'] <= 1.00) & (master_projections['Position']=='TE'), :]['Nickname'].values)
out_players = list(master_projections.loc[(master_projections['Injury Indicator'] == 'IR') | (master_projections['Injury Indicator'] == 'O'), :]['Nickname'].values)
low_scorers = list(master_projections.loc[master_projections['FPPG'] < 1.00, :]['Nickname'].values)

# fade_players from footballers DFS article
# wrs_bad_matchups

all_removals = low_tes + out_players + low_scorers

# %%
'Mike Gesicki' in all_removals
# Out:
# True

# %%
optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('projections/Week-10/master_projections.csv')

# Removing certain players
for each_player in all_removals:
    optimizer.remove_player(each_player)

# Setting positional constraints
optimizer.set_players_with_same_position({'TE': 0})
# optimizer.set_positions_for_same_team(['QB', 'WR'])
# optimizer.set_positions_for_same_team(['RB', 'D'])

# Generating 12 lineups
for lineup in optimizer.optimize(n=12, max_exposure= .15, randomness=True):
    print(lineup, '\n')
# Out:
#  1. QB    Aaron Rodgers                 QB    GB             3.3     8600.0$
#  2. RB    Kareem Hunt                   RB    KC             3.6     9000.0$
#  3. RB    Dion Lewis                    RB    TEN            2.0     5800.0$
#  4. WR    Josh Gordon                   WR    NE             2.2     6700.0$
#  5. WR    Cooper Kupp                   WR    LAR            2.4     6500.0$
#  6. WR    Jarvis Landry                 WR    CLE            2.4     6400.0$
#  7. TE    O.J. Howard                   TE    TB             2.4     6500.0$
#  8. D     Kansas City Chiefs            D     KC             3.9     4600.0$
#  9. FLEX  Jared Cook                    TE    OAK            2.0     5500.0$
#
# Fantasy Points 24.2
# Salary 59600.0
#
#  1. QB    Ryan Fitzpatrick              QB    TB             2.6     7600.0$
#  2. RB    Kareem Hunt                   RB    KC             3.6     9000.0$
#  3. RB    Elijah McGuire                RB    NYJ            1.4     4900.0$
#  4. WR    Cooper Kupp                   WR    LAR            2.4     6500.0$
#  5. WR    Jarvis Landry                 WR    CLE            2.4     6400.0$
#  6. WR    Michael Thomas                WR    NO             3.4     8600.0$
#  7. TE    Jared Cook                    TE    OAK            2.0     5500.0$
#  8. D     New York Jets                 D     NYJ            4.4     4900.0$
#  9. FLEX  Jordan Howard                 RB    CHI            2.2     6500.0$
#
# Fantasy Points 24.4
# Salary 59900.0
#
#  1. QB    Ryan Fitzpatrick              QB    TB             2.6     7600.0$
#  2. RB    David Johnson                 RB    ARI            2.6     6900.0$
#  3. RB    Dion Lewis                    RB    TEN            2.0     5800.0$
#  4. WR    Michael Thomas                WR    NO             3.4     8600.0$
#  5. WR    Corey Davis                   WR    TEN            1.9     5800.0$
#  6. WR    Kenny Golladay                WR    DET            2.2     5800.0$
#  7. TE    Travis Kelce                  TE    KC             2.8     8000.0$
#  8. D     New York Jets                 D     NYJ            4.4     4900.0$
#  9. FLEX  O.J. Howard                   TE    TB             2.4     6500.0$
#
# Fantasy Points 24.3
# Salary 59900.0
#
#  1. QB    Jared Goff                    QB    LAR            2.9     8100.0$
#  2. RB    David Johnson                 RB    ARI            2.6     6900.0$
#  3. RB    Jordan Howard                 RB    CHI            2.2     6500.0$
#  4. WR    Tyreek Hill                   WR    KC             2.7     7600.0$
#  5. WR    Robert Woods                  WR    LAR            2.5     7500.0$
#  6. WR    Kenny Golladay                WR    DET            2.2     5800.0$
#  7. TE    Travis Kelce                  TE    KC             2.8     8000.0$
#  8. D     Green Bay Packers             D     GB             3.3     3900.0$
#  9. FLEX  Jack Doyle                    TE    IND            1.9     5600.0$
#
# Fantasy Points 23.1
# Salary 59900.0
#
#  1. QB    Jared Goff                    QB    LAR            2.9     8100.0$
#  2. RB    Tevin Coleman                 RB    ATL            2.2     7300.0$
#  3. RB    Isaiah Crowell                RB    NYJ            1.6     5400.0$
#  4. WR    Keenan Allen                  WR    LAC            2.6     7900.0$
#  5. WR    Tyreek Hill                   WR    KC             2.7     7600.0$
#  6. WR    Davante Adams                 WR    GB             2.6     8600.0$
#  7. TE    Eric Ebron                    TE    IND            1.6     5400.0$
#  8. D     Green Bay Packers             D     GB             3.3     3900.0$
#  9. FLEX  Larry Fitzgerald              WR    ARI            1.9     5800.0$
#
# Fantasy Points 21.4
# Salary 60000.0
#
#  1. QB    Aaron Rodgers                 QB    GB             3.3     8600.0$
#  2. RB    Nick Chubb                    RB    CLE            2.4     6700.0$
#  3. RB    Tarik Cohen                   RB    CHI            1.9     6400.0$
#  4. WR    Keenan Allen                  WR    LAC            2.6     7900.0$
#  5. WR    Robert Woods                  WR    LAR            2.5     7500.0$
#  6. WR    Josh Gordon                   WR    NE             2.2     6700.0$
#  7. TE    Jack Doyle                    TE    IND            1.9     5600.0$
#  8. D     Kansas City Chiefs            D     KC             3.9     4600.0$
#  9. FLEX  Larry Fitzgerald              WR    ARI            1.9     5800.0$
#
# Fantasy Points 22.6
# Salary 59800.0
#
#  1. QB    Drew Brees                    QB    NO             2.9     8400.0$
#  2. RB    Joe Mixon                     RB    CIN            2.4     8000.0$
#  3. RB    James White                   RB    NE             2.3     7800.0$
#  4. WR    Marquez Valdes-Scantling      WR    GB             1.7     5400.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.3     7700.0$
#  6. WR    Christian Kirk                WR    ARI            1.6     5400.0$
#  7. TE    Eric Ebron                    TE    IND            1.6     5400.0$
#  8. D     Chicago Bears                 D     CHI            3.1     5000.0$
#  9. FLEX  Nick Chubb                    RB    CLE            2.4     6700.0$
#
# Fantasy Points 20.3
# Salary 59800.0
#
#  1. QB    Drew Brees                    QB    NO             2.9     8400.0$
#  2. RB    Alvin Kamara                  RB    NO             2.6     8800.0$
#  3. RB    Aaron Jones                   RB    GB             2.1     6500.0$
#  4. WR    Marquez Valdes-Scantling      WR    GB             1.7     5400.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.3     7700.0$
#  6. WR    DeSean Jackson                WR    TB             1.9     6300.0$
#  7. TE    Trey Burton                   TE    CHI            1.8     6100.0$
#  8. D     Chicago Bears                 D     CHI            3.1     5000.0$
#  9. FLEX  Corey Davis                   WR    TEN            1.9     5800.0$
#
# Fantasy Points 20.3
# Salary 60000.0
#
#  1. QB    Matt Ryan                     QB    ATL            2.5     8500.0$
#  2. RB    Tevin Coleman                 RB    ATL            2.2     7300.0$
#  3. RB    Tarik Cohen                   RB    CHI            1.9     6400.0$
#  4. WR    Julio Jones                   WR    ATL            2.8     8700.0$
#  5. WR    Davante Adams                 WR    GB             2.6     8600.0$
#  6. WR    Donte Moncrief                WR    JAC            1.5     5500.0$
#  7. TE    Trey Burton                   TE    CHI            1.8     6100.0$
#  8. D     Washington Redskins           D     WAS            2.7     3400.0$
#  9. FLEX  Isaiah Crowell                RB    NYJ            1.6     5400.0$
#
# Fantasy Points 19.6
# Salary 59900.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.0     9800.0$
#  2. RB    Joe Mixon                     RB    CIN            2.4     8000.0$
#  3. RB    Elijah McGuire                RB    NYJ            1.4     4900.0$
#  4. WR    Julio Jones                   WR    ATL            2.8     8700.0$
#  5. WR    DeSean Jackson                WR    TB             1.9     6300.0$
#  6. WR    Donte Moncrief                WR    JAC            1.5     5500.0$
#  7. TE    Benjamin Watson               TE    NO             1.4     5900.0$
#  8. D     New England Patriots          D     NE             2.8     4200.0$
#  9. FLEX  Aaron Jones                   RB    GB             2.1     6500.0$
#
# Fantasy Points 19.3
# Salary 59800.0
#
#  1. QB    Matt Ryan                     QB    ATL            2.5     8500.0$
#  2. RB    James White                   RB    NE             2.3     7800.0$
#  3. RB    Alvin Kamara                  RB    NO             2.6     8800.0$
#  4. WR    Tyler Boyd                    WR    CIN            2.1     7800.0$
#  5. WR    Tyrell Williams               WR    LAC            1.6     6500.0$
#  6. WR    Tyler Lockett                 WR    SEA            1.8     6200.0$
#  7. TE    Gerald Everett                TE    LAR            1.0     4500.0$
#  8. D     New England Patriots          D     NE             2.8     4200.0$
#  9. FLEX  LeSean McCoy                  RB    BUF            1.6     5600.0$
#
# Fantasy Points 18.3
# Salary 59900.0
#
#  1. QB    Philip Rivers                 QB    LAC            2.6     8200.0$
#  2. RB    Adrian Peterson               RB    WAS            2.0     6800.0$
#  3. RB    Mike Davis                    RB    SEA            1.7     5800.0$
#  4. WR    Tyler Boyd                    WR    CIN            2.1     7800.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.8     7000.0$
#  6. WR    Tyrell Williams               WR    LAC            1.6     6500.0$
#  7. TE    Austin Hooper                 TE    ATL            1.4     5800.0$
#  8. D     Washington Redskins           D     WAS            2.7     3400.0$
#  9. FLEX  Christian Kirk                WR    ARI            1.6     5400.0$
#
# Fantasy Points 17.5
# Salary 56700.0

# %%
exporter = CSVLineupExporter(optimizer.optimize(n=20, max_exposure= .15, randomness=True))
exporter.export('submissions/Week-10/fanduel-lineups.csv')
