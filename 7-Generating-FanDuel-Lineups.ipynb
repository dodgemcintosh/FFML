# %% [markdown]
# # Using Optimization Techniques to Generate Winning FanDuel Lineups
# ___
# Until I build one from scratch I'm going to be testing out `pydfs-lineup-optimizer` to generate optimal lineups with projections that I already have. More information about `pydfs-lineup-optimizer` can be found [here](https://github.com/DimaKudosh/pydfs-lineup-optimizer/tree/master/pydfs_lineup_optimizer/sites/fanduel).

# %% [markdown]
# **Here is one quick example of generating lineups based on average points per game.**

# %%
import pandas as pd
from pydfs_lineup_optimizer import get_optimizer, Site, Sport, CSVLineupExporter

# %%
optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('player-lists/Week-13/FanDuel-NFL-2018-12-02-30514-players-list.csv')
for lineup in optimizer.optimize(n=5, max_exposure=0.3):
    print(lineup.players)
    print(lineup.fantasy_points_projection)
    print(lineup.salary_costs)
# Out:
# [Ryan Fitzpatrick QB (TB), Todd Gurley II RB (LAR), James White RB (NE), Tyreek Hill WR (KC), John Brown WR (BAL), Leonte Carroo WR (MIA), Travis Kelce TE (KC), Minnesota Vikings D (MIN), Saquon Barkley RB (NYG)]
# 149.521
# 60000.0
# [Ryan Fitzpatrick QB (TB), Todd Gurley II RB (LAR), T.J. Yeldon RB (JAC), Tyreek Hill WR (KC), John Brown WR (BAL), Leonte Carroo WR (MIA), Travis Kelce TE (KC), Chicago Bears D (CHI), Saquon Barkley RB (NYG)]
# 149.185
# 59500.0
# [Patrick Mahomes QB (KC), T.J. Yeldon RB (JAC), Christian McCaffrey RB (CAR), Davante Adams WR (GB), Sterling Shepard WR (NYG), Emmanuel Sanders WR (DEN), Nick O'Leary TE (MIA), Chicago Bears D (CHI), James White RB (NE)]
# 138.664
# 59800.0
# [Patrick Mahomes QB (KC), Kareem Hunt RB (KC), Joe Mixon RB (CIN), Jarvis Landry WR (CLE), Sterling Shepard WR (NYG), Emmanuel Sanders WR (DEN), Nick O'Leary TE (MIA), Minnesota Vikings D (MIN), Christian McCaffrey RB (CAR)]
# 133.31
# 60000.0
# [Jared Goff QB (LAR), Kareem Hunt RB (KC), Mike Davis RB (SEA), Davante Adams WR (GB), Dede Westbrook WR (JAC), Tyler Boyd WR (CIN), George Kittle TE (SF), Arizona Cardinals D (ARI), Joe Mixon RB (CIN)]
# 128.021
# 60000.0

# %%
problematic_names_dict = {'Melvin Gordon':'Melvin Gordon III', 'Odell Beckham':'Odell Beckham Jr.',\
                          'Will Fuller':'Will Fuller V', 'Marvin Jones':'Marvin Jones Jr.',\
                          'Willie Snead':'Willie Snead IV', 'Ted Ginn':'Ted Ginn Jr.', \
                          'Allen Robinson':'Allen Robinson II', 'Patrick Mahomes II':'Patrick Mahomes'}

# %% [markdown]
# ## Now instead of just using the average points per game, we'll bring in our other projections that *should* be more accurate.

# %% [markdown]
# ___
# #### 1. Ballers

# %%
current_week = 13

qbs = pd.read_csv('projections/Week-{}/DFS - Fanduel QB.csv'.format(current_week))
rbs = pd.read_csv('projections/Week-{}/DFS - Fanduel RB.csv'.format(current_week))
wrs = pd.read_csv('projections/Week-{}/DFS - Fanduel WR.csv'.format(current_week))
tes = pd.read_csv('projections/Week-{}/DFS - Fanduel TE.csv'.format(current_week))
dst = pd.read_csv('projections/Week-{}/DFS - Fanduel DST.csv'.format(current_week))
full_team_names = list(dst.sort_values('Player')['Player'])

# %%
footballers = pd.concat([qbs,rbs,wrs,tes,dst])
footballers.rename(columns={"Player": "Nickname"}, inplace=True)
footballers.Nickname.replace(problematic_names_dict, inplace=True)

# %% [markdown]
# ___
# #### 2. Sportsline

# %%
sportsline = pd.read_csv('projections/Week-{}/projections.csv'.format(current_week))
sportsline.rename(columns={"PLAYER": "Nickname"}, inplace=True)
sportsline.Nickname.replace(problematic_names_dict, inplace=True)
abbv_team_names = list(sportsline.loc[sportsline.POS == 'DEF', :].sort_values('Nickname')['Nickname'])
defenses_dict = dict(zip(abbv_team_names, full_team_names))
sportsline['Nickname'].replace(defenses_dict, inplace = True)
sportsline.head(2)
# Out:
#           Nickname POS TEAM   OPP    FP  fd exp  dk exp   PPR CONS% FREB%  \
# 0  Patrick Mahomes  QB   KC  @OAK  35.8    24.2    28.2  35.8   60%   50%
# 1       Jared Goff  QB  LAR  @DET  29.2    21.4    23.7  29.2   62%   40%
#
#    PASSYD  RUSHYD  RECYD
# 0   373.0    20.0    NaN
# 1   349.0     7.0    NaN

# %% [markdown]
# ___
# #### 3. FantasyPros

# %%
fp_qb = pd.read_csv('projections/Week-{}/FantasyPros_Fantasy_Football_Projections_QB.csv'.format(current_week))
fp_rb = pd.read_csv('projections/Week-{}/FantasyPros_Fantasy_Football_Projections_RB.csv'.format(current_week))
fp_wr = pd.read_csv('projections/Week-{}/FantasyPros_Fantasy_Football_Projections_WR.csv'.format(current_week))
fp_te = pd.read_csv('projections/Week-{}/FantasyPros_Fantasy_Football_Projections_TE.csv'.format(current_week))
fp_dst = pd.read_csv('projections/Week-{}/FantasyPros_Fantasy_Football_Projections_DST.csv'.format(current_week))

# %%
for df in [fp_qb, fp_rb, fp_wr, fp_te, fp_dst]:
    df.drop([col for col in df.columns if col not in ['Player', 'FPTS']], axis=1, inplace=True)

# %%
fantasy_pros = pd.concat([fp_qb, fp_rb, fp_wr, fp_te, fp_dst])
fantasy_pros.rename(columns={"Player": "Nickname"}, inplace=True)
fantasy_pros.Nickname.replace(problematic_names_dict, inplace=True)

# %% [markdown]
# ___
# #### Averaging the projections:

# %%
total_projections = pd.merge(footballers, sportsline, on="Nickname")
total_projections = pd.merge(total_projections, fantasy_pros, on="Nickname")
total_projections['Salary'] = total_projections.Salary.apply(lambda x: int(x.replace(',', '')))
total_projections['Pts'] = (total_projections.Pts + total_projections.FP + total_projections.FPTS) / 3
total_projections['Pts Per 1k'] = total_projections['Pts'] / (total_projections.Salary / 1000)
total_projections.drop(labels=list(total_projections.columns[5:]), axis=1, inplace=True)
total_projections.head(3)
# Out:
#           Nickname     Opp        Pts  Salary  Pts Per 1k
# 0       Cam Newton   at TB  26.100000    8700    3.000000
# 1       Jared Goff  at DET  25.666667    8400    3.055556
# 2  Patrick Mahomes  at OAK  29.833333    9500    3.140351

# %%
total_projections.loc[total_projections.Nickname == 'Matt Breida', :]
# Out:
#        Nickname     Opp        Pts  Salary  Pts Per 1k
# 44  Matt Breida  at SEA  12.733333    6400    1.989583

# %% [markdown]
# ___
# #### Bringing in the player list from FanDuel:

# %%
# Make sure you're selecting the correct file:
player_list=pd.read_csv('player-lists/Week-13/FanDuel-NFL-2018-12-02-30514-players-list.csv')
player_list.head(3)
# Out:
#             Id Position First Name         Nickname  Last Name       FPPG  \
# 0  30514-30447       RB       Todd   Todd Gurley II  Gurley II  25.081818
# 1  30514-57439       QB    Patrick  Patrick Mahomes    Mahomes  28.156364
# 2  30514-45229       RB     Kareem      Kareem Hunt       Hunt  19.745454
#
#    Played  Salary     Game Team Opponent Injury Indicator Injury Details  \
# 0      11    9800  LAR@DET  LAR      DET              NaN            NaN
# 1      11    9500   KC@OAK   KC      OAK              NaN            NaN
# 2      11    8900   KC@OAK   KC      OAK              NaN            NaN
#
#    Tier  Unnamed: 14  Unnamed: 15
# 0   NaN          NaN          NaN
# 1   NaN          NaN          NaN
# 2   NaN          NaN          NaN

# %%
player_list.loc[player_list.Nickname == 'Matt Breida', :]
# Out:
#              Id Position First Name     Nickname Last Name       FPPG  Played  \
# 63  30514-53303       RB       Matt  Matt Breida    Breida  11.509091      11
#
#     Salary    Game Team Opponent Injury Indicator Injury Details  Tier  \
# 63    6400  SF@SEA   SF      SEA                Q          Ankle   NaN
#
#     Unnamed: 14  Unnamed: 15
# 63          NaN          NaN

# %% [markdown]
# > Merging those 2 and making the swap:

# %%
master_projections = pd.merge(left=player_list, right=total_projections, how='inner', on='Nickname', suffixes=['_FD', '_tp'])
master_projections['FPPG'] = master_projections['Pts Per 1k'] # Experiment with Pts OR Pts Per 1k
master_projections.drop(['Opp', 'Pts', 'Salary_tp', 'Pts Per 1k'],axis=1, inplace=True)
master_projections.rename(columns={'Salary_FD':'Salary'}, inplace=True)
master_projections.to_csv('projections/Week-{}/master_FD_projections.csv'.format(current_week))
master_projections.head(3)
# Out:
#             Id Position First Name         Nickname Last Name      FPPG  \
# 0  30514-57439       QB    Patrick  Patrick Mahomes   Mahomes  3.140351
# 1  30514-45229       RB     Kareem      Kareem Hunt      Hunt  2.509363
# 2  30514-16606       WR    DeAndre  DeAndre Hopkins   Hopkins  2.125000
#
#    Played  Salary     Game Team Opponent Injury Indicator Injury Details  \
# 0      11    9500   KC@OAK   KC      OAK              NaN            NaN
# 1      11    8900   KC@OAK   KC      OAK              NaN            NaN
# 2      11    8800  CLE@HOU  HOU      CLE                Q           Foot
#
#    Tier  Unnamed: 14  Unnamed: 15
# 0   NaN          NaN          NaN
# 1   NaN          NaN          NaN
# 2   NaN          NaN          NaN

# %%
master_projections.loc[master_projections.Position == 'D', :].sort_values('FPPG', ascending= False)[:5]
# Out:
#               Id Position   First Name          Nickname Last Name      FPPG  \
# 210  30514-12538        D  Los Angeles  Los Angeles Rams      Rams  2.934959
# 148  30514-12527        D      Chicago     Chicago Bears     Bears  2.840278
# 211  30514-12538        D  Los Angeles  Los Angeles Rams      Rams  2.821138
# 167  30514-12550        D      Seattle  Seattle Seahawks  Seahawks  2.811594
# 195  30514-12534        D    Tennessee  Tennessee Titans    Titans  2.598485
#
#      Played  Salary     Game Team Opponent Injury Indicator Injury Details  \
# 210      11    4100  LAR@DET  LAR      DET              NaN            NaN
# 148      11    4800  CHI@NYG  CHI      NYG              NaN            NaN
# 211      11    4100  LAR@DET  LAR      DET              NaN            NaN
# 167      11    4600   SF@SEA  SEA       SF              NaN            NaN
# 195      11    4400  NYJ@TEN  TEN      NYJ              NaN            NaN
#
#      Tier  Unnamed: 14  Unnamed: 15
# 210   NaN          NaN          NaN
# 148   NaN          NaN          NaN
# 211   NaN          NaN          NaN
# 167   NaN          NaN          NaN
# 195   NaN          NaN          NaN

# %%
master_projections.loc[(master_projections.Nickname == 'Adam Thielen'), :]
# Out:
#              Id Position First Name      Nickname Last Name      FPPG  Played  \
# 14  30514-39716       WR       Adam  Adam Thielen   Thielen  2.016461      11
#
#     Salary    Game Team Opponent Injury Indicator Injury Details  Tier  \
# 14    8100  MIN@NE  MIN       NE                Q           Calf   NaN
#
#     Unnamed: 14  Unnamed: 15
# 14          NaN          NaN

# %% [markdown]
# ___
# # Alright! Now let's just use our optimizer tools from above to generate some better lineups

# %%
out_players = list(master_projections.loc[(master_projections['Injury Indicator'] == 'IR') | (master_projections['Injury Indicator'] == 'O'), :]['Nickname'].values)
low_scorers = list(master_projections.loc[master_projections['FPPG'] < 0.80, :]['Nickname'].values)

all_removals = out_players + low_scorers
all_removals = list(set(all_removals))

# %%
optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('projections/Week-{}/master_FD_projections.csv'.format(current_week))

# Removing certain players
for each_player in all_removals:
    optimizer.remove_player(each_player)

# Setting positional constraints
# optimizer.set_players_with_same_position({'TE': 0})
# No stacking on this one

# Making more randomness
optimizer.set_deviation(0.00, 0.16)

# Setting a minimum salary cap
optimizer.set_min_salary_cap(58000)

# Generating 20 lineups
for lineup in optimizer.optimize(n=13, max_exposure=.25):
    print(lineup, '\n')
# Out:
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  3. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            2.489   8800.0$
#
# Fantasy Points 21.08
# Salary 60000.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Aaron Jones                   RB    GB             2.43    7600.0$
#
# Fantasy Points 20.992
# Salary 59900.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  3. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            2.489   8800.0$
#
# Fantasy Points 20.971
# Salary 59800.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  3. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            2.489   8800.0$
#
# Fantasy Points 20.966
# Salary 60000.0
#
#  1. QB    Russell Wilson                QB    SEA            2.887   7700.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  4. WR    Demaryius Thomas              WR    HOU            1.56    5300.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  6. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  7. TE    Travis Kelce                  TE    KC             2.107   7800.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            2.162   7000.0$
#
# Fantasy Points 19.91
# Salary 59500.0
#
#  1. QB    Russell Wilson                QB    SEA            2.887   7700.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  4. WR    Demaryius Thomas              WR    HOU            1.56    5300.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  6. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  7. TE    Travis Kelce                  TE    KC             2.107   7800.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            2.162   7000.0$
#
# Fantasy Points 19.797
# Salary 59500.0
#
#  1. QB    Russell Wilson                QB    SEA            2.887   7700.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    Phillip Lindsay               RB    DEN            2.162   7000.0$
#  4. WR    Demaryius Thomas              WR    HOU            1.56    5300.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  6. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  7. TE    Travis Kelce                  TE    KC             2.107   7800.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Dion Lewis                    RB    TEN            1.861   5500.0$
#
# Fantasy Points 19.764
# Salary 60000.0
#
#  1. QB    Russell Wilson                QB    SEA            2.887   7700.0$
#  2. RB    Christian McCaffrey           RB    CAR            2.489   8800.0$
#  3. RB    Phillip Lindsay               RB    DEN            2.162   7000.0$
#  4. WR    Demaryius Thomas              WR    HOU            1.56    5300.0$
#  5. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  6. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  7. TE    Travis Kelce                  TE    KC             2.107   7800.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Dion Lewis                    RB    TEN            1.861   5500.0$
#
# Fantasy Points 19.743
# Salary 59900.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  3. RB    Lamar Miller                  RB    HOU            2.005   6300.0$
#  4. WR    Mike Evans                    WR    TB             1.852   7900.0$
#  5. WR    Doug Baldwin                  WR    SEA            1.651   6200.0$
#  6. WR    Davante Adams                 WR    GB             2.024   8500.0$
#  7. TE    Rob Gronkowski                TE    NE             1.826   6700.0$
#  8. D     Seattle Seahawks              D     SEA            2.812   4600.0$
#  9. FLEX  Dion Lewis                    RB    TEN            1.861   5500.0$
#
# Fantasy Points 18.955
# Salary 60000.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  3. RB    Lamar Miller                  RB    HOU            2.005   6300.0$
#  4. WR    Emmanuel Sanders              WR    DEN            1.757   7000.0$
#  5. WR    Doug Baldwin                  WR    SEA            1.651   6200.0$
#  6. WR    Davante Adams                 WR    GB             2.024   8500.0$
#  7. TE    Rob Gronkowski                TE    NE             1.826   6700.0$
#  8. D     Seattle Seahawks              D     SEA            2.812   4600.0$
#  9. FLEX  Chris Carson                  RB    SEA            1.921   6300.0$
#
# Fantasy Points 18.92
# Salary 59900.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    Lamar Miller                  RB    HOU            2.005   6300.0$
#  3. RB    Chris Carson                  RB    SEA            1.921   6300.0$
#  4. WR    Courtland Sutton              WR    DEN            1.481   5400.0$
#  5. WR    Emmanuel Sanders              WR    DEN            1.757   7000.0$
#  6. WR    Davante Adams                 WR    GB             2.024   8500.0$
#  7. TE    Rob Gronkowski                TE    NE             1.826   6700.0$
#  8. D     Chicago Bears                 D     CHI            2.84    4800.0$
#  9. FLEX  Dion Lewis                    RB    TEN            1.861   5500.0$
#
# Fantasy Points 18.855
# Salary 60000.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    Saquon Barkley                RB    NYG            2.174   8600.0$
#  3. RB    Lamar Miller                  RB    HOU            2.005   6300.0$
#  4. WR    John Brown                    WR    BAL            1.417   4800.0$
#  5. WR    Emmanuel Sanders              WR    DEN            1.757   7000.0$
#  6. WR    Doug Baldwin                  WR    SEA            1.651   6200.0$
#  7. TE    Rob Gronkowski                TE    NE             1.826   6700.0$
#  8. D     Seattle Seahawks              D     SEA            2.812   4600.0$
#  9. FLEX  Chris Carson                  RB    SEA            1.921   6300.0$
#
# Fantasy Points 18.703
# Salary 60000.0
#
#  1. QB    Jameis Winston                QB    TB             2.671   7500.0$
#  2. RB    David Johnson                 RB    ARI            1.991   7500.0$
#  3. RB    Chris Carson                  RB    SEA            1.921   6300.0$
#  4. WR    Emmanuel Sanders              WR    DEN            1.757   7000.0$
#  5. WR    Doug Baldwin                  WR    SEA            1.651   6200.0$
#  6. WR    Davante Adams                 WR    GB             2.024   8500.0$
#  7. TE    Jared Cook                    TE    OAK            1.565   6200.0$
#  8. D     Seattle Seahawks              D     SEA            2.812   4600.0$
#  9. FLEX  Dalvin Cook                   RB    MIN            1.79    6200.0$
#
# Fantasy Points 18.18
# Salary 60000.0

# %%
exporter = CSVLineupExporter(optimizer.optimize(n=20, max_exposure=.25))
exporter.export('submissions/Week-{}/fanduel-lineups-nostacks.csv'.format(current_week))

# %%
optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('projections/Week-{}/master_FD_projections.csv'.format(current_week))

# Removing certain players
for each_player in all_removals:
    optimizer.remove_player(each_player)

# Setting positional constraints
optimizer.set_players_with_same_position({'TE': 0})
optimizer.set_positions_for_same_team(['QB', 'WR'])

# Making more randomness
optimizer.set_deviation(0.06, .24)

# Setting a minimum salary cap
optimizer.set_min_salary_cap(58000)

# Capping the number of repeating players
optimizer.set_max_repeating_players(5)

# Generating 20 lineups
for lineup in optimizer.optimize(n=30, max_exposure=.35):
    print(lineup, '\n')
# Out:
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  3. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            2.489   8800.0$
#
# Fantasy Points 21.08
# Salary 60000.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  3. RB    Phillip Lindsay               RB    DEN            2.162   7000.0$
#  4. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Lamar Miller                  RB    HOU            2.005   6300.0$
#
# Fantasy Points 20.754
# Salary 60000.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  4. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  5. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.806   5500.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Aaron Jones                   RB    GB             2.43    7600.0$
#
# Fantasy Points 20.748
# Salary 59600.0
#
#  1. QB    Patrick Mahomes               QB    KC             3.14    9500.0$
#  2. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  3. RB    Aaron Jones                   RB    GB             2.43    7600.0$
#  4. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  5. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  6. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            2.162   7000.0$
#
# Fantasy Points 20.681
# Salary 59700.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    Carlos Hyde                   RB    JAC            1.893   5000.0$
#  4. WR    Brandin Cooks                 WR    LAR            2.094   7800.0$
#  5. WR    Corey Davis                   WR    TEN            1.763   5900.0$
#  6. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.935   4100.0$
#  9. FLEX  Lamar Miller                  RB    HOU            2.005   6300.0$
#
# Fantasy Points 20.636
# Salary 59700.0
#
#  1. QB    Jared Goff                    QB    LAR            3.056   8400.0$
#  2. RB    Kareem Hunt                   RB    KC             2.509   8900.0$
#  3. RB    T.J. Yeldon                   RB    JAC            1.785   4800.0$
#  4. WR    Demaryius Thomas              WR    HOU            1.56    5300.0$
#  5. WR    Robert Woods                  WR    LAR            2.091   7300.0$
#  6. WR    Tyreek Hill                   WR    KC             2.448   8400.0$
#  7. TE    Cameron Brate                 TE    TB             1.932   4900.0$
#  8. D     Los Angeles Rams              D     LAR            2.821   4100.0$
#  9. FLEX  Aaron Jones                   RB    GB             2.43    7600.0$
#
# Fantasy Points 20.632
# Salary 59700.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-532c7a14f99c> in <module>()
#      21
#      22 # Generating 20 lineups
# ---> 23 for lineup in optimizer.optimize(n=30, max_exposure=.35):
#      24     print(lineup, '\n')
#
# /anaconda3/lib/python3.6/site-packages/pydfs_lineup_optimizer/lineup_optimizer.py in optimize(self, n, max_exposure, randomness, with_injured)
#     381                 constraint.apply_for_iteration(solver, players_dict, previous_lineup)
#     382             try:
# --> 383                 solved_variables = solver.solve()
#     384                 lineup_players = []
#     385                 for solved_variable in solved_variables:
#
# /anaconda3/lib/python3.6/site-packages/pydfs_lineup_optimizer/solvers/pulp_solver.py in solve(self)
#      37
#      38     def solve(self):
# ---> 39         self.prob.solve()
#      40         if self.prob.status == LpStatusOptimal:
#      41             result = []
#
# /anaconda3/lib/python3.6/site-packages/pulp/pulp.py in solve(self, solver, **kwargs)
#    1662         #time it
#    1663         self.solutionTime = -clock()
# -> 1664         status = solver.actualSolve(self, **kwargs)
#    1665         self.solutionTime += clock()
#    1666         self.restoreObjective(wasNone, dummyVar)
#
# /anaconda3/lib/python3.6/site-packages/pulp/solvers.py in actualSolve(self, lp, **kwargs)
#    1360     def actualSolve(self, lp, **kwargs):
#    1361         """Solve a well formulated lp problem"""
# -> 1362         return self.solve_CBC(lp, **kwargs)
#    1363
#    1364     def available(self):
#
# /anaconda3/lib/python3.6/site-packages/pulp/solvers.py in solve_CBC(self, lp, use_mps)
#    1419         cbc = subprocess.Popen((self.path + cmds).split(), stdout = pipe,
#    1420                              stderr = pipe)
# -> 1421         if cbc.wait() != 0:
#    1422             raise PulpSolverError("Pulp: Error while trying to execute " +  \
#    1423                                     self.path)
#
# /anaconda3/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1455                         if self.returncode is not None:
#    1456                             break  # Another thread waited.
# -> 1457                         (pid, sts) = self._try_wait(0)
#    1458                         # Check the pid and loop as waitpid has been known to
#    1459                         # return 0 even without WNOHANG in odd situations.
#
# /anaconda3/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1402             """All callers to this function MUST hold self._waitpid_lock."""
#    1403             try:
# -> 1404                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1405             except ChildProcessError:
#    1406                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
exporter = CSVLineupExporter(optimizer.optimize(n=20, max_exposure=.25))
exporter.export('submissions/Week-{}/fanduel-lineups-qbwr.csv'.format(current_week))

# %%
# Doing the second half with a RB + D stack

optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('projections/Week-{}/master_FD_projections.csv'.format(current_week))

# Removing certain players
for each_player in all_removals:
    optimizer.remove_player(each_player)

# Setting positional constraints
optimizer.set_players_with_same_position({'TE': 0})
optimizer.set_positions_for_same_team(['RB', 'D'])

    
# Making more randomness
optimizer.set_deviation(0.06, 0.24)

# Setting a minimum salary cap
optimizer.set_min_salary_cap(58000)

# Generating 20 lineups
for lineup in optimizer.optimize(n=20, max_exposure=.25):
    print(lineup, '\n')
# Out:
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  5. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.937
# Salary 59900.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  5. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.912
# Salary 59500.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    JuJu Smith-Schuster           WR    PIT            1.597   7200.0$
#  5. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.838
# Salary 59200.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  5. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.834
# Salary 58800.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  5. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.821
# Salary 59000.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  6. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Cleveland Browns              D     CLE            2.376   3100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            1.905   8400.0$
#
# Fantasy Points 16.804
# Salary 59900.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Keenan Allen                  WR    LAC            1.671   7700.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  6. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Cleveland Browns              D     CLE            2.376   3100.0$
#  9. FLEX  Marlon Mack                   RB    IND            1.805   7000.0$
#
# Fantasy Points 16.794
# Salary 59900.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Cleveland Browns              D     CLE            2.376   3100.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            1.905   8400.0$
#
# Fantasy Points 16.772
# Salary 60000.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  6. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Cleveland Browns              D     CLE            2.376   3100.0$
#  9. FLEX  Marlon Mack                   RB    IND            1.805   7000.0$
#
# Fantasy Points 16.766
# Salary 60000.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Keenan Allen                  WR    LAC            1.671   7700.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  6. WR    Emmanuel Sanders              WR    DEN            1.551   6900.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Cleveland Browns              D     CLE            2.376   3100.0$
#  9. FLEX  Marlon Mack                   RB    IND            1.805   7000.0$
#
# Fantasy Points 16.751
# Salary 60000.0
#
#  1. QB    Carson Wentz                  QB    PHI            2.333   7700.0$
#  2. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  3. RB    Marlon Mack                   RB    IND            1.805   7000.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    Keenan Allen                  WR    LAC            1.671   7700.0$
#  6. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  7. TE    Eric Ebron                    TE    IND            1.406   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Leonard Fournette             RB    JAC            1.568   8100.0$
#
# Fantasy Points 16.226
# Salary 59900.0
#  1. QB    Lamar Jackson                 QB    BAL            2.311   7400.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Marlon Mack                   RB    IND            1.805   7000.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    Keenan Allen                  WR    LAC            1.671   7700.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Eric Ebron                    TE    IND            1.406   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Leonard Fournette             RB    JAC            1.568   8100.0$
#
# Fantasy Points 16.157
# Salary 59800.0
#
#  1. QB    Ryan Tannehill                QB    MIA            2.197   6600.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Christian McCaffrey           RB    CAR            1.905   8400.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    JuJu Smith-Schuster           WR    PIT            1.597   7200.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Eric Ebron                    TE    IND            1.406   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Leonard Fournette             RB    JAC            1.568   8100.0$
#
# Fantasy Points 16.07
# Salary 59900.0
#
#  1. QB    Ryan Tannehill                QB    MIA            2.197   6600.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Christian McCaffrey           RB    CAR            1.905   8400.0$
#  4. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  5. WR    Courtland Sutton              WR    DEN            1.426   5400.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Eric Ebron                    TE    IND            1.406   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Leonard Fournette             RB    JAC            1.568   8100.0$
#
# Fantasy Points 16.051
# Salary 59900.0
#
#  1. QB    Ryan Tannehill                QB    MIA            2.197   6600.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Christian McCaffrey           RB    CAR            1.905   8400.0$
#  4. WR    Emmanuel Sanders              WR    DEN            1.551   6900.0$
#  5. WR    Courtland Sutton              WR    DEN            1.426   5400.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Eric Ebron                    TE    IND            1.406   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Leonard Fournette             RB    JAC            1.568   8100.0$
#
# Fantasy Points 16.009
# Salary 60000.0
#
#  1. QB    Lamar Jackson                 QB    BAL            2.311   7400.0$
#  2. RB    David Johnson                 RB    ARI            1.768   7900.0$
#  3. RB    James White                   RB    NE             1.523   7400.0$
#  4. WR    Keenan Allen                  WR    LAC            1.671   7700.0$
#  5. WR    Emmanuel Sanders              WR    DEN            1.551   6900.0$
#  6. WR    Courtland Sutton              WR    DEN            1.426   5400.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     New England Patriots          D     NE             2.382   4100.0$
#  9. FLEX  Kenyan Drake                  RB    MIA            1.467   5500.0$
#
# Fantasy Points 15.694
# Salary 59900.0
#
#  1. QB    Carson Wentz                  QB    PHI            2.333   7700.0$
#  2. RB    David Johnson                 RB    ARI            1.768   7900.0$
#  3. RB    James White                   RB    NE             1.523   7400.0$
#  4. WR    JuJu Smith-Schuster           WR    PIT            1.597   7200.0$
#  5. WR    Emmanuel Sanders              WR    DEN            1.551   6900.0$
#  6. WR    Courtland Sutton              WR    DEN            1.426   5400.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     New England Patriots          D     NE             2.382   4100.0$
#  9. FLEX  Kenyan Drake                  RB    MIA            1.467   5500.0$
#
# Fantasy Points 15.643
# Salary 59700.0
#
#  1. QB    Ryan Tannehill                QB    MIA            2.197   6600.0$
#  2. RB    David Johnson                 RB    ARI            1.768   7900.0$
#  3. RB    James White                   RB    NE             1.523   7400.0$
#  4. WR    JuJu Smith-Schuster           WR    PIT            1.597   7200.0$
#  5. WR    Emmanuel Sanders              WR    DEN            1.551   6900.0$
#  6. WR    Courtland Sutton              WR    DEN            1.426   5400.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     New England Patriots          D     NE             2.382   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            1.588   6800.0$
#
# Fantasy Points 15.628
# Salary 59900.0
#
#  1. QB    Lamar Jackson                 QB    BAL            2.311   7400.0$
#  2. RB    David Johnson                 RB    ARI            1.768   7900.0$
#  3. RB    James White                   RB    NE             1.523   7400.0$
#  4. WR    JuJu Smith-Schuster           WR    PIT            1.597   7200.0$
#  5. WR    Tyler Lockett                 WR    SEA            1.466   6300.0$
#  6. WR    John Brown                    WR    BAL            1.373   5100.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     New England Patriots          D     NE             2.382   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            1.588   6800.0$
#
# Fantasy Points 15.603
# Salary 59800.0
#
#  1. QB    Carson Wentz                  QB    PHI            2.333   7700.0$
#  2. RB    David Johnson                 RB    ARI            1.768   7900.0$
#  3. RB    James White                   RB    NE             1.523   7400.0$
#  4. WR    Josh Gordon                   WR    NE             1.534   6800.0$
#  5. WR    Tyler Lockett                 WR    SEA            1.466   6300.0$
#  6. WR    John Brown                    WR    BAL            1.373   5100.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     New England Patriots          D     NE             2.382   4100.0$
#  9. FLEX  Phillip Lindsay               RB    DEN            1.588   6800.0$
#
# Fantasy Points 15.563
# Salary 59700.0

# %%
exporter = CSVLineupExporter(optimizer.optimize(n=20, max_exposure=.25))
exporter.export('submissions/Week-{}/fanduel-lineups-rbdst.csv'.format(current_week))

# %%
# QB + TE stack

optimizer = get_optimizer(Site.FANDUEL, Sport.FOOTBALL)

optimizer.load_players_from_csv('projections/Week-{}/master_FD_projections.csv'.format(current_week))

# Removing certain players
for each_player in all_removals:
    optimizer.remove_player(each_player)

# Setting positional constraints
optimizer.set_players_with_same_position({'TE': 0})
optimizer.set_positions_for_same_team(['QB', 'TE'])

# Making more randomness
optimizer.set_deviation(0.06, 0.24)

# Setting a minimum salary cap
# optimizer.set_min_salary_cap(57000)

# Generating 20 lineups
for lineup in optimizer.optimize(n=5, max_exposure=.35):
    print(lineup, '\n')
# Out:
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  5. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Matt Breida                   RB    SF             1.948   6400.0$
#
# Fantasy Points 17.835
# Salary 59900.0
#
#  1. QB    Jameis Winston                QB    TB             2.436   7500.0$
#  2. RB    James Conner                  RB    PIT            2.008   7900.0$
#  3. RB    Matt Breida                   RB    SF             1.948   6400.0$
#  4. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  5. WR    Antonio Brown                 WR    PIT            1.855   8500.0$
#  6. WR    Jarvis Landry                 WR    CLE            1.683   6100.0$
#  7. TE    Cameron Brate                 TE    TB             1.765   4400.0$
#  8. D     Baltimore Ravens              D     BAL            2.707   5000.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 17.821
# Salary 59000.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  3. RB    Joe Mixon                     RB    CIN            1.84    7300.0$
#  4. WR    Mike Evans                    WR    TB             1.696   7900.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  6. WR    Tyler Boyd                    WR    CIN            1.593   6800.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Philadelphia Eagles           D     PHI            2.474   3800.0$
#  9. FLEX  Gus Edwards                   RB    BAL            1.723   5300.0$
#
# Fantasy Points 16.951
# Salary 60000.0
#
#  1. QB    Andrew Luck                   QB    IND            2.552   8400.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Nick Chubb                    RB    CLE            1.862   7500.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    T.Y. Hilton                   WR    IND            1.671   7500.0$
#  6. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  7. TE    Jack Doyle                    TE    IND            1.539   5500.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Marlon Mack                   RB    IND            1.805   7000.0$
#
# Fantasy Points 16.826
# Salary 60000.0
#
#  1. QB    Carson Wentz                  QB    PHI            2.333   7700.0$
#  2. RB    Saquon Barkley                RB    NYG            1.941   9000.0$
#  3. RB    Marlon Mack                   RB    IND            1.805   7000.0$
#  4. WR    Quincy Enunwa                 WR    NYJ            1.44    5000.0$
#  5. WR    Kenny Stills                  WR    MIA            1.447   5300.0$
#  6. WR    John Brown                    WR    BAL            1.373   5100.0$
#  7. TE    Zach Ertz                     TE    PHI            1.596   7600.0$
#  8. D     Jacksonville Jaguars          D     JAC            2.569   4800.0$
#  9. FLEX  Christian McCaffrey           RB    CAR            1.905   8400.0$
#
# Fantasy Points 16.409
# Salary 59900.0

# %%
exporter = CSVLineupExporter(optimizer.optimize(n=20, max_exposure=.25))
exporter.export('submissions/Week-{}/fanduel-lineups-qbte.csv'.format(current_week))
